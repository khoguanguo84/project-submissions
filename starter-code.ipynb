# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Choose your Data
#
# There are 2 datasets included in the [`data`](./data/) folder for this project. These correponds to rainfall information.
#
# * [`rainfall-monthly-number-of-rain-days.csv`](./data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](./data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
#
# Other relevant weather datasets from [data.gov.sg](data.gov.sg) that you can download and use are as follows:
#
# * [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean)
# * [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total)
# * [Hourly wet buld temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly)
# * [Monthly mean sunshine hours](https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration)
# * [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum)
#
# You can also use other datasets for your analysis, make sure to cite the source when you are using them

# %% [markdown]
# ##### Weather related Datasets
#
# rainfall-monthly-total.csv: Monthly total rain recorded in mm(millimeters) from 1982 to 2022.
#
# rainfall-monthly-number-of-rain-days.csv: Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
#
# sunshine-duration-monthly-mean-daily-duration.csv: The monthly mean sunshine hours in a day recorded at the Changi Climate Station from 1982 to 2022.
#
# rainfall-monthly-highest-daily-total.csv: The highest daily total rainfall for the month recorded at the Changi Climate Station recorded in mm(millimeters) from 1982 to 2022.
#
# All above datasets provided in data folder for Project 1 obtained from [data.gov.sg](data.gov.sg)
#
# ##### Traffic Accident related Datasets
#
# traffic_accident_statistics.csv: Traffic accident data reflected as accidents per month between 2008 to 2021 to include both accidents resulting in fatalities, and caused injury.
#
# Traffic accident dataset obtained from https://www.police.gov.sg/-/media/1F7F9460FD8F48928B6DEFE096414975.ashx, table 1a and converted into a csv file.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# It was reported in 2013 that more accidents occur on days of thunderstorms. Traffic accidents cause road congestion and Traffic Police and Civil Defence resources need to be deployed to help ease this. By using climate information on rainfall and traffic accident statistics, this project aims to help Traffic Police and Civil Defence better facilitate manpower and resource allocation throughout the year by identifying trends between traffic accidents and weather.
#
# https://www.straitstimes.com/singapore/more-road-accidents-on-days-of-thunderstorms (reported in 2013)

# %% [markdown]
# Rainfall affects daily activities of Singapore population, hence it is worth analysing rainfall data to identify trends

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on how climate change is affecting different industries or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# I have quoted the title of an article cited below, (1), in my problem statement as it quite aptly summed up the problem. I also google searched for relavent data to be used for my project. I have taken the traffic accident data from the cited source below, (2), specifically table 1a which comprises of data that reflects accidents per month between 2008 to 2021 to include both accidents resulting in fatalities, and caused injury as this would affect how Civil Defence resources are deployed.
#
# The further along the project I got, it became clear that I may have to recommend an expansion on the data required of this project to properly aid in truly efficient resource allocation. I then took some experiences from the US (3) and how weather may affect road conditions there to see what other statistics can be recommended for an improved version of this study.
#
#
# 1. https://www.straitstimes.com/singapore/more-road-accidents-on-days-of-thunderstorms (reported in 2013)
#
# 2. https://www.police.gov.sg/-/media/1F7F9460FD8F48928B6DEFE096414975.ashx (published statistics from SPF 2021)
#
# 3. https://ops.fhwa.dot.gov/weather/q1_roadimpact.htm

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def find_mean(numlst):
    mean = sum(numlst)/len(numlst)
    return mean

numlst = [1, 3, 2, 4, 7, 11, 9, 3]
find_mean(numlst)
# Out:
# 5.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def find_std_dev(numlst):
    mean = sum(numlst)/len(numlst)
    for num in numlst: 
        deviations = [(num - mean) ** 2]
        variance = sum(deviations)/len(numlst)
        std_dev = variance ** 0.5
    return std_dev

numlst = [1, 3, 2, 4, 7, 11, 9, 3]

round(find_std_dev(numlst), 4)
# Out:
# 0.7071

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Import sunshine-duration-monthly-mean-daily-duration.csv
sunshine_dur = pd.read_csv("../data/sunshine-duration-monthly-mean-daily-duration.csv")

# %%
# Check type
sunshine_dur.dtypes
# Out:
# month                 object
# mean_sunshine_hrs    float64
# dtype: object

# %%
# Convert month and year to date time format
pd.to_datetime(sunshine_dur["month"])
# Out:
# 0     1982-01-01
# 1     1982-02-01
# 2     1982-03-01
# 3     1982-04-01
# 4     1982-05-01
#          ...
# 486   2022-07-01
# 487   2022-08-01
# 488   2022-09-01
# 489   2022-10-01
# 490   2022-11-01
# Name: month, Length: 491, dtype: datetime64[ns]

# %%
# Show first 5 rows
sunshine_dur.head()
# Out:
#      month  mean_sunshine_hrs
# 0  1982-01                5.6
# 1  1982-02                7.6
# 2  1982-03                5.1
# 3  1982-04                4.7
# 4  1982-05                5.8

# %%
# Import rainfall-monthly-highest-daily-total.csv
mth_highest_rain = pd.read_csv("../data/rainfall-monthly-highest-daily-total.csv")

# %%
# Checking data type
mth_highest_rain.dtypes
# Out:
# month                         object
# maximum_rainfall_in_a_day    float64
# dtype: object

# %%
# Convert month and year to date time format
pd.to_datetime(mth_highest_rain["month"])
# Out:
# 0     1982-01-01
# 1     1982-02-01
# 2     1982-03-01
# 3     1982-04-01
# 4     1982-05-01
#          ...
# 486   2022-07-01
# 487   2022-08-01
# 488   2022-09-01
# 489   2022-10-01
# 490   2022-11-01
# Name: month, Length: 491, dtype: datetime64[ns]

# %%
# Show first 5 rows
mth_highest_rain.head()
# Out:
#      month  maximum_rainfall_in_a_day
# 0  1982-01                       36.5
# 1  1982-02                        9.4
# 2  1982-03                       61.7
# 3  1982-04                       45.1
# 4  1982-05                       33.0

# %%
# Import rainfall-monthly-number-of-rain-days.csv
mth_rain_days = pd.read_csv("../data/rainfall-monthly-number-of-rain-days.csv")

# %%
# Checking data type
mth_rain_days.dtypes
# Out:
# month               object
# no_of_rainy_days     int64
# dtype: object

# %%
# Show first 5 rows
mth_rain_days.head()
# Out:
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10

# %%
# Convert month column into datetime format
pd.to_datetime(mth_rain_days["month"])
# Out:
# 0     1982-01-01
# 1     1982-02-01
# 2     1982-03-01
# 3     1982-04-01
# 4     1982-05-01
#          ...
# 483   2022-04-01
# 484   2022-05-01
# 485   2022-06-01
# 486   2022-07-01
# 487   2022-08-01
# Name: month, Length: 488, dtype: datetime64[ns]

# %%
# Import rainfall-monthly-total.csv
mth_rain_total = pd.read_csv("../data/rainfall-monthly-total.csv")

# %%
# Show first 5 rows
mth_rain_total.head()
# Out:
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2

# %%
# Convert month column into datetime format
pd.to_datetime(mth_rain_total["month"])
# Out:
# 0     1982-01-01
# 1     1982-02-01
# 2     1982-03-01
# 3     1982-04-01
# 4     1982-05-01
#          ...
# 483   2022-04-01
# 484   2022-05-01
# 485   2022-06-01
# 486   2022-07-01
# 487   2022-08-01
# Name: month, Length: 488, dtype: datetime64[ns]

# %%
# Merge the dataframes 2 at a time based on the month column
rain_stat1 = pd.merge(left = mth_highest_rain,
        right = mth_rain_days,
        on = 'month')

# %%
rain_stat1
# Out:
#        month  maximum_rainfall_in_a_day  no_of_rainy_days
# 0    1982-01                       36.5                10
# 1    1982-02                        9.4                 5
# 2    1982-03                       61.7                11
# 3    1982-04                       45.1                14
# 4    1982-05                       33.0                10
# ..       ...                        ...               ...
# 483  2022-04                       58.8                18
# 484  2022-05                       44.6                12
# 485  2022-06                       59.4                17
# 486  2022-07                       27.8                16
# 487  2022-08                       32.4                15
#
# [488 rows x 3 columns]

# %%
rain_stat2 = pd.merge(left = rain_stat1,
        right = mth_rain_total,
        on = 'month')

# %%
rain_stat2
# Out:
#        month  maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall
# 0    1982-01                       36.5                10           107.1
# 1    1982-02                        9.4                 5            27.8
# 2    1982-03                       61.7                11           160.8
# 3    1982-04                       45.1                14           157.0
# 4    1982-05                       33.0                10           102.2
# ..       ...                        ...               ...             ...
# 483  2022-04                       58.8                18           239.6
# 484  2022-05                       44.6                12           102.0
# 485  2022-06                       59.4                17           211.8
# 486  2022-07                       27.8                16           145.2
# 487  2022-08                       32.4                15           141.4
#
# [488 rows x 4 columns]

# %%
rain_stat3 = pd.merge(left = rain_stat2,
        right = sunshine_dur,
        on = 'month')

# %%
rain_stat3
# Out:
#        month  maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# 0    1982-01                       36.5                10           107.1
# 1    1982-02                        9.4                 5            27.8
# 2    1982-03                       61.7                11           160.8
# 3    1982-04                       45.1                14           157.0
# 4    1982-05                       33.0                10           102.2
# ..       ...                        ...               ...             ...
# 483  2022-04                       58.8                18           239.6
# 484  2022-05                       44.6                12           102.0
# 485  2022-06                       59.4                17           211.8
# 486  2022-07                       27.8                16           145.2
# 487  2022-08                       32.4                15           141.4
#
#      mean_sunshine_hrs
# 0                  5.6
# 1                  7.6
# ...

# %%
# Convert the month column to datetime format
rain_stat3["month"] = pd.to_datetime(rain_stat3["month"])

# %%
# Creating columns for month and year separately
rain_stat3["mth"] = rain_stat3['month'].dt.month

# %%
rain_stat3["year"] = rain_stat3['month'].dt.year

# %%
rain_stat3.head()
# Out:
#        month  maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# 0 1982-01-01                       36.5                10           107.1
# 1 1982-02-01                        9.4                 5            27.8
# 2 1982-03-01                       61.7                11           160.8
# 3 1982-04-01                       45.1                14           157.0
# 4 1982-05-01                       33.0                10           102.2
#
#    mean_sunshine_hrs  mth  year
# 0                5.6    1  1982
# 1                7.6    2  1982
# 2                5.1    3  1982
# 3                4.7    4  1982
# 4                5.8    5  1982

# %%
# Import traffic_accident_statistics.csv taken from Singapore Police published report converted to CSV file
# https://www.police.gov.sg/-/media/1F7F9460FD8F48928B6DEFE096414975.ashx
accident_stats = pd.read_csv("../data/traffic_accident_statistics.csv")

# %%
# Statistics shown are based on car accidents that resulted in either injury, or fatalities
accident_stats
# Out:
#     year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 0   2008  750  606  713  718  706  714  760  757  747  735  676  708
# 1   2009  709  660  712  704  719  693  707  751  687  764  772  729
# 2   2010  680  665  780  726  777  666  763  811  752  786  744  658
# 3   2011  799  634  709  728  695  673  730  738  737  744  705  705
# 4   2012  691  707  708  677  686  577  690  723  684  681  670  690
# 5   2013  691  612  640  665  642  597  639  656  649  673  645  639
# 6   2014  676  558  604  639  684  657  704  768  667  675  676  651
# 7   2015  638  648  770  645  687  646  714  694  626  686  712  740
# 8   2016  703  697  666  684  695  655  746  794  668  740  753  643
# 9   2017  689  592  676  674  641  636  686  663  629  619  686  652
# 10  2018  713  618  668  648  614  654  626  667  618  642  710  632
# 11  2019  677  581  624  635  660  655  687  622  659  692  676  654
# 12  2020  647  489  520  296  262  365  479  437  476  512  485  588
# ...

# %%
# Checking type
accident_stats.dtypes
# Out:
# year    int64
# Jan     int64
# Feb     int64
# Mar     int64
# Apr     int64
# May     int64
# Jun     int64
# Jul     int64
# Aug     int64
# Sep     int64
# Oct     int64
# Nov     int64
# Dec     int64
# dtype: object

# %%
# Convert accident_stats using pd.melt so that it will be easier to merge with the rainfall statistics dataframe later on
accident_stats2 = pd.melt(accident_stats, id_vars=['year'])
accident_stats2.head()
# Out:
#    year variable  value
# 0  2008      Jan    750
# 1  2009      Jan    709
# 2  2010      Jan    680
# 3  2011      Jan    799
# 4  2012      Jan    691

# %%
# Rename the columns to match other 2 dataframes

accident_stats2.rename(
    columns={"variable": "month", "value": "num_of_accidents"},
    inplace=True,)

# %%
accident_stats2
# Out:
#      year month  num_of_accidents
# 0    2008   Jan               750
# 1    2009   Jan               709
# 2    2010   Jan               680
# 3    2011   Jan               799
# 4    2012   Jan               691
# ..    ...   ...               ...
# 163  2017   Dec               652
# 164  2018   Dec               632
# 165  2019   Dec               654
# 166  2020   Dec               588
# 167  2021   Dec               525
#
# [168 rows x 3 columns]

# %%
#accident_stats2['month'].map({'Jan': 1,'Feb': 2,'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6, 'Jul': 7, 'Aug': 8, 'Sep':9, 'Oct': 10, 'Nov': 11, 'Dec': 12})
# Replace Month column values into integers to facilitate visualisation and EDA later on
accident_stats2 = accident_stats2.replace(to_replace = "Jan",value = 1)
accident_stats2 = accident_stats2.replace(to_replace = "Feb",value = 2)
accident_stats2 = accident_stats2.replace(to_replace = "Mar",value = 3)
accident_stats2 = accident_stats2.replace(to_replace = "Apr",value = 4)
accident_stats2 = accident_stats2.replace(to_replace = "May",value = 5)
accident_stats2 = accident_stats2.replace(to_replace = "Jun",value = 6)
accident_stats2 = accident_stats2.replace(to_replace = "Jul",value = 7)
accident_stats2 = accident_stats2.replace(to_replace = "Aug",value = 8)
accident_stats2 = accident_stats2.replace(to_replace = "Sep",value = 9)
accident_stats2 = accident_stats2.replace(to_replace = "Oct",value = 10)
accident_stats2 = accident_stats2.replace(to_replace = "Nov",value = 11)
accident_stats2 = accident_stats2.replace(to_replace = "Dec",value = 12)

# %%
# To check against the number of rows after merging
accident_stats2.shape
# Out:
# (168, 3)

# %%
# Merging rain/sunshine (rain_stat3) with accident data (accident_stats2). Only on data from 2008 to 2021.
accident_rain = rain_stat3.merge(accident_stats2, left_on = ['year', 'mth'], right_on = ['year', 'month'])

# %%
accident_rain
# Out:
#        month_x  maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# 0   2008-01-01                      123.1                19           262.6
# 1   2008-02-01                       48.5                 8           129.2
# 2   2008-03-01                       48.1                16           294.1
# 3   2008-04-01                       34.2                13            87.2
# 4   2008-05-01                       42.3                11           124.9
# ..         ...                        ...               ...             ...
# 163 2021-08-01                       71.4                24           293.6
# 164 2021-09-01                       63.4                14           205.4
# 165 2021-10-01                       59.6                14           177.0
# 166 2021-11-01                       47.8                23           312.4
# 167 2021-12-01                       46.8                15           119.6
#
# ...

# %%
# Rename columns after merge to reflect data how clearly
accident_rain = accident_rain.rename(columns={'month_x': 'mth_year'})

# %%
accident_rain
# Out:
#       mth_year  maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# 0   2008-01-01                      123.1                19           262.6
# 1   2008-02-01                       48.5                 8           129.2
# 2   2008-03-01                       48.1                16           294.1
# 3   2008-04-01                       34.2                13            87.2
# 4   2008-05-01                       42.3                11           124.9
# ..         ...                        ...               ...             ...
# 163 2021-08-01                       71.4                24           293.6
# 164 2021-09-01                       63.4                14           205.4
# 165 2021-10-01                       59.6                14           177.0
# 166 2021-11-01                       47.8                23           312.4
# 167 2021-12-01                       46.8                15           119.6
#
# ...

# %%
# Drop duplicate coloumn
accident_rain = accident_rain.drop('month_y', axis = 1)

# %%
# Reorder the columns to make it easier to read
accident_rain2 = accident_rain[accident_rain.columns[[0, 5, 6, 3, 1, 2, 4, 7]]]

# %%
accident_rain2
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 0   2008-01-01    1  2008           262.6                      123.1
# 1   2008-02-01    2  2008           129.2                       48.5
# 2   2008-03-01    3  2008           294.1                       48.1
# 3   2008-04-01    4  2008            87.2                       34.2
# 4   2008-05-01    5  2008           124.9                       42.3
# ..         ...  ...   ...             ...                        ...
# 163 2021-08-01    8  2021           293.6                       71.4
# 164 2021-09-01    9  2021           205.4                       63.4
# 165 2021-10-01   10  2021           177.0                       59.6
# 166 2021-11-01   11  2021           312.4                       47.8
# 167 2021-12-01   12  2021           119.6                       46.8
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 0                  19                6.1               750
# ...

# %%
accident_rain2.dtypes
# Out:
# mth_year                     datetime64[ns]
# mth                                   int64
# year                                  int64
# total_rainfall                      float64
# maximum_rainfall_in_a_day           float64
# no_of_rainy_days                      int64
# mean_sunshine_hrs                   float64
# num_of_accidents                      int64
# dtype: object

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |total_rainfall|float|rainfall-monthly-total.csv| Monthly total rain recorded in mm(millimeters) from 1982 to 2022.|
# |maximum_rainfall_in_a_day|float|rainfall-monthly-highest-daily-total.csv|The highest daily total rainfall for the month recorded at the Changi Climate Station recorded in mm(millimeters) from 1982 to 2022.|
# |no_of_rainy_days|integer|rainfall-monthly-number-of-rain-days.csv|Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.|
# |mean_sunshine_hrs|float|sunshine-duration-monthly-mean-daily-duration.csv|The monthly mean sunshine hours in a day recorded at the Changi Climate Station from 1982 to 2022.|
# |num_of_accidents|integer|traffic_accident_statistics.csv|Traffic accident data reflected as accidents per month between 2008 to 2021 to include both accidents resulting in fatalities, and caused injury.|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
def find_std_dev(numlst):
    mean = sum(numlst)/len(numlst)
    for num in numlst: 
        deviations = [(num - mean) ** 2]
        variance = sum(deviations)/len(numlst)
        std_dev = variance ** 0.5
    return round(std_dev, 4)

# %%
sd = {col: find_std_dev(accident_rain2[col]) for col in accident_rain2.columns[3:]}

# %%
sd
# Out:
# {'total_rainfall': 3.7839,
#  'maximum_rainfall_in_a_day': 0.0679,
#  'no_of_rainy_days': 0.0372,
#  'mean_sunshine_hrs': 0.0347,
#  'num_of_accidents': 10.1092}

# %%
accident_rain2.head()
# Out:
#     mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 0 2008-01-01    1  2008           262.6                      123.1
# 1 2008-02-01    2  2008           129.2                       48.5
# 2 2008-03-01    3  2008           294.1                       48.1
# 3 2008-04-01    4  2008            87.2                       34.2
# 4 2008-05-01    5  2008           124.9                       42.3
#
#    no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 0                19                6.1               750
# 1                 8                5.5               606
# 2                16                4.3               713
# 3                13                6.0               718
# 4                11                6.6               706

# %%
def high_low_rainfall(accident_rain2, 'total_rain_fall', 'year', 'month', asc):
    yr = accident_rain2[accident_rain2['year'] == 2010]
    yr.sort_values('total_rainfall', ascending=asc)
# Out:
# Series([], Name: total_rainfall, dtype: float64)

# %%
# due to lack of data for the years asked after merging, will find values for 2010, 2015, 2018 and 2020

accident_rain2010 = accident_rain2[accident_rain2['year'] == 2010]
accident_rain2015 = accident_rain2[accident_rain2['year'] == 2015]
accident_rain2018 = accident_rain2[accident_rain2['year'] == 2018]
accident_rain2020 = accident_rain2[accident_rain2['year'] == 2020]

# %%
# minimum total rainfall in 2010
accident_rain2010.sort_values(by = 'total_rainfall', ascending = True).head(1)
# Out:
#      mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 25 2010-02-01    2  2010             6.3                        2.9
#
#     no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 25                 4                8.8               665

# %%
# maximum total rainfall in 2010
accident_rain2010.sort_values(by = 'total_rainfall', ascending = False).head(1)
# Out:
#      mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 30 2010-07-01    7  2010           298.5                      121.1
#
#     no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 30                18                4.6               763

# %%
# minimum total rainfall in 2015
accident_rain2015.sort_values(by = 'total_rainfall', ascending = True).head(1)
# Out:
#      mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 85 2015-02-01    2  2015            18.8                       10.8
#
#     no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 85                 6                7.3               648

# %%
# maximum total rainfall in 2015
accident_rain2015.sort_values(by = 'total_rainfall', ascending = False).head(1)
# Out:
#      mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 95 2015-12-01   12  2015           302.3                       40.4
#
#     no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 95                19                5.3               740

# %%
# minimum total rainfall in 2018
accident_rain2018.sort_values(by = 'total_rainfall', ascending = True).head(1)
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 121 2018-02-01    2  2018            14.8                       13.0
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 121                 5                8.0               618

# %%
# maximum total rainfall in 2018
accident_rain2018.sort_values(by = 'total_rainfall', ascending = False).head(1)
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 120 2018-01-01    1  2018           287.0                       45.8
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 120                25                4.1               713

# %%
# minimum total rainfall in 2020
accident_rain2020.sort_values(by = 'total_rainfall', ascending = True).head(1)
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 145 2020-02-01    2  2020            65.0                       23.8
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 145                 8                8.3               489

# %%
# maximum total rainfall in 2020
accident_rain2020.sort_values(by = 'total_rainfall', ascending = False).head(1)
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 148 2020-05-01    5  2020           255.6                       53.8
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 148                16                5.7               262

# %%
# highest total rainfall in the date range
accident_rain2.sort_values(by = 'total_rainfall', ascending = False).head(1)
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 156 2021-01-01    1  2021           692.8                      210.6
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 156                17                4.2               556

# %%
# creating a dataframe by yearly totals
all_totals_yr = accident_rain2.groupby('year').sum()

# %%
all_totals_yr
# Out:
#       mth  total_rainfall  maximum_rainfall_in_a_day  no_of_rainy_days  \
# year
# 2008   78          2325.1                      699.2               182
# 2009   78          1920.9                      565.5               166
# 2010   78          2075.1                      653.3               178
# 2011   78          2524.2                      786.2               188
# 2012   78          2159.9                      575.5               191
# 2013   78          2748.4                      744.8               206
# 2014   78          1538.4                      407.0               152
# 2015   78          1267.1                      382.0               125
# 2016   78          1955.7                      592.6               179
# 2017   78          2045.6                      465.0               204
# 2018   78          1708.2                      419.2               188
# 2019   78          1367.5                      454.4               120
# ...

# %%
# year with the highest total rainfall
all_totals_yr.sort_values(by = 'total_rainfall', ascending = False).head(1)
# Out:
#       mth  total_rainfall  maximum_rainfall_in_a_day  no_of_rainy_days  \
# year
# 2021   78          2809.6                      770.6               182
#
#       mean_sunshine_hrs  num_of_accidents
# year
# 2021               73.5              6039

# %%
# year with the lowest total rainfall
all_totals_yr.sort_values(by = 'total_rainfall', ascending = True).head(1)
# Out:
#       mth  total_rainfall  maximum_rainfall_in_a_day  no_of_rainy_days  \
# year
# 2015   78          1267.1                      382.0               125
#
#       mean_sunshine_hrs  num_of_accidents
# year
# 2015               74.0              8206

# %%
# due to lack of data for the years asked after merging, will find values for 2010, 2015, 2018 and 2020
# highest and lowest number of rainy days in the above mentioned years
# month with minimum number of rainy days in 2010
accident_rain2010.sort_values(by = 'no_of_rainy_days', ascending = True).head(1)
# Out:
#      mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 25 2010-02-01    2  2010             6.3                        2.9
#
#     no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 25                 4                8.8               665

# %%
# month with maximum number of rainy days in 2010
accident_rain2010.sort_values(by = 'no_of_rainy_days', ascending = False).head(1)
# Out:
#      mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 34 2010-11-01   11  2010           278.8                       41.6
#
#     no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 34                21                5.0               744

# %%
# month with minimum number of rainy days in 2015
accident_rain2015.sort_values(by = 'no_of_rainy_days', ascending = True).head(1)
# Out:
#      mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 86 2015-03-01    3  2015            84.4                       46.0
#
#     no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 86                 5                7.3               770

# %%
# month with maximum number of rainy days in 2015
accident_rain2015.sort_values(by = 'no_of_rainy_days', ascending = False).head(1)
# Out:
#      mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 95 2015-12-01   12  2015           302.3                       40.4
#
#     no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 95                19                5.3               740

# %%
# month with minimum number of rainy days in 2018
accident_rain2018.sort_values(by = 'no_of_rainy_days', ascending = True).head(1)
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 121 2018-02-01    2  2018            14.8                       13.0
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 121                 5                8.0               618

# %%
# month with maximum number of rainy days in 2018
accident_rain2018.sort_values(by = 'no_of_rainy_days', ascending = False).head(1)
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 130 2018-11-01   11  2018           169.6                       20.6
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 130                27                3.8               710

# %%
# month with minimum number of rainy days in 2020
accident_rain2020.sort_values(by = 'no_of_rainy_days', ascending = True).head(1)
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 144 2020-01-01    1  2020            88.4                       38.0
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 144                 6                7.1               647

# %%
# month with maximum number of rainy days in 2020
accident_rain2020.sort_values(by = 'no_of_rainy_days', ascending = False).head(1)
# Out:
#       mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 150 2020-07-01    7  2020           140.8                       30.4
#
#      no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 150                22                5.7               479

# %%
# year with the highest number of rainy days
all_totals_yr.sort_values(by = 'no_of_rainy_days', ascending = False).head(1)
# Out:
#       mth  total_rainfall  maximum_rainfall_in_a_day  no_of_rainy_days  \
# year
# 2013   78          2748.4                      744.8               206
#
#       mean_sunshine_hrs  num_of_accidents
# year
# 2013               65.2              7748

# %%
# year with the lowest number of rainy days
all_totals_yr.sort_values(by = 'no_of_rainy_days', ascending = True).head(1)
# Out:
#       mth  total_rainfall  maximum_rainfall_in_a_day  no_of_rainy_days  \
# year
# 2019   78          1367.5                      454.4               120
#
#       mean_sunshine_hrs  num_of_accidents
# year
# 2019               81.4              7822

# %%
accident_rain2.head()
# Out:
#     mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 0 2008-01-01    1  2008           262.6                      123.1
# 1 2008-02-01    2  2008           129.2                       48.5
# 2 2008-03-01    3  2008           294.1                       48.1
# 3 2008-04-01    4  2008            87.2                       34.2
# 4 2008-05-01    5  2008           124.9                       42.3
#
#    no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 0                19                6.1               750
# 1                 8                5.5               606
# 2                16                4.3               713
# 3                13                6.0               718
# 4                11                6.6               706

# %%
# Using boxplots to find potential outliers for all the different categories being measured.

sns.boxplot(x = accident_rain2.total_rainfall, orient = 'h')
# Out:
# <AxesSubplot:xlabel='total_rainfall'>

# %%
sns.boxplot(x = accident_rain2.maximum_rainfall_in_a_day, orient = 'h')
# Out:
# <AxesSubplot:xlabel='maximum_rainfall_in_a_day'>

# %%
sns.boxplot(x = accident_rain2.no_of_rainy_days, orient = 'h')
# Out:
# <AxesSubplot:xlabel='no_of_rainy_days'>

# %%
sns.boxplot(x = accident_rain2.mean_sunshine_hrs, orient = 'h')
# Out:
# <AxesSubplot:xlabel='mean_sunshine_hrs'>

# %%
sns.boxplot(x = accident_rain2.num_of_accidents, orient = 'h')
# Out:
# <AxesSubplot:xlabel='num_of_accidents'>

# %%
all_totals_yr
# Out:
#       mth  total_rainfall  maximum_rainfall_in_a_day  no_of_rainy_days  \
# year
# 2008   78          2325.1                      699.2               182
# 2009   78          1920.9                      565.5               166
# 2010   78          2075.1                      653.3               178
# 2011   78          2524.2                      786.2               188
# 2012   78          2159.9                      575.5               191
# 2013   78          2748.4                      744.8               206
# 2014   78          1538.4                      407.0               152
# 2015   78          1267.1                      382.0               125
# 2016   78          1955.7                      592.6               179
# 2017   78          2045.6                      465.0               204
# 2018   78          1708.2                      419.2               188
# 2019   78          1367.5                      454.4               120
# ...

# %%
accident_rain2.head()
# Out:
#     mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 0 2008-01-01    1  2008           262.6                      123.1
# 1 2008-02-01    2  2008           129.2                       48.5
# 2 2008-03-01    3  2008           294.1                       48.1
# 3 2008-04-01    4  2008            87.2                       34.2
# 4 2008-05-01    5  2008           124.9                       42.3
#
#    no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 0                19                6.1               750
# 1                 8                5.5               606
# 2                16                4.3               713
# 3                13                6.0               718
# 4                11                6.6               706

# %%
# using .corr() to find correlations between number of accidents against the rainfall statistics by month
accident_rain2.corr()
# Out:
#                                     mth          year  total_rainfall  \
# mth                        1.000000e+00  9.959861e-15        0.235565
# year                       9.959861e-15  1.000000e+00       -0.067713
# total_rainfall             2.355650e-01 -6.771309e-02        1.000000
# maximum_rainfall_in_a_day  7.149143e-02 -1.252222e-01        0.806579
# no_of_rainy_days           4.409684e-01 -6.049229e-02        0.676074
# mean_sunshine_hrs         -5.293049e-01  1.868535e-01       -0.632086
# num_of_accidents           7.438188e-02 -6.652992e-01        0.049246
#
#                            maximum_rainfall_in_a_day  no_of_rainy_days  \
# mth                                         0.071491          0.440968
# year                                       -0.125222         -0.060492
# total_rainfall                              0.806579          0.676074
# maximum_rainfall_in_a_day                   1.000000          0.399688
# ...

# %%
# using .corr() to find correlations between number of accidents against the rainfall statistics by year
all_totals_yr.corr()
# Out:
#                            mth  total_rainfall  maximum_rainfall_in_a_day  \
# mth                        NaN             NaN                        NaN
# total_rainfall             NaN        1.000000                   0.917682
# maximum_rainfall_in_a_day  NaN        0.917682                   1.000000
# no_of_rainy_days           NaN        0.765282                   0.537311
# mean_sunshine_hrs          NaN       -0.590781                  -0.489074
# num_of_accidents           NaN       -0.154900                   0.037072
#
#                            no_of_rainy_days  mean_sunshine_hrs  \
# mth                                     NaN                NaN
# total_rainfall                     0.765282          -0.590781
# maximum_rainfall_in_a_day          0.537311          -0.489074
# no_of_rainy_days                   1.000000          -0.769023
# mean_sunshine_hrs                 -0.769023           1.000000
# num_of_accidents                  -0.073053          -0.247892
#
# ...

# %% [markdown]
# ##### Initial Findings
# 1. There were no significant patterns or correlations when matching each metric with Traffic Accident statistics from the EDA done.
# 2. It was noted that there were significantly more outliers for Accident Statistics as compared to the rest of the weather data which warrants further investigation.
# 3. It was noted that 2020 and 2021 were covid lockdown years which significantly reduced the total number of accidents in those 2 years. (perhaps road usage data should be used to compare next to weather data and accident statistics to form a more robust study)

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %%
all_totals_yr1 = all_totals_yr.drop('mth', axis = 1)

# %%
all_totals_yr1.head()
# Out:
#       total_rainfall  maximum_rainfall_in_a_day  no_of_rainy_days  \
# year
# 2008          2325.1                      699.2               182
# 2009          1920.9                      565.5               166
# 2010          2075.1                      653.3               178
# 2011          2524.2                      786.2               188
# 2012          2159.9                      575.5               191
#
#       mean_sunshine_hrs  num_of_accidents
# year
# 2008               62.9              8590
# 2009               71.4              8607
# 2010               68.3              8808
# 2011               66.9              8597
# 2012               66.4              8184

# %%
# Checking correlation between Rainfall Statistics and Traffic Accident Statistics by year.
plt.figure(figsize = (14,7))


corr = all_totals_yr1.corr()


mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True


with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmax = 1, linewidths = .5)
    
plt.title('Correlation Between Rainfall Statistics and Traffic Accidents by Year');

# %%
accident_rain3 = accident_rain2.drop(['mth', 'year'], axis = 1)

# %%
accident_rain3.head()
# Out:
#     mth_year  total_rainfall  maximum_rainfall_in_a_day  no_of_rainy_days  \
# 0 2008-01-01           262.6                      123.1                19
# 1 2008-02-01           129.2                       48.5                 8
# 2 2008-03-01           294.1                       48.1                16
# 3 2008-04-01            87.2                       34.2                13
# 4 2008-05-01           124.9                       42.3                11
#
#    mean_sunshine_hrs  num_of_accidents
# 0                6.1               750
# 1                5.5               606
# 2                4.3               713
# 3                6.0               718
# 4                6.6               706

# %%
# Checking correlation between Rainfall Statistics and Traffic Accident Statistics by month.
plt.figure(figsize = (14,7))


corr1 = accident_rain3.corr()


mask = np.zeros_like(corr1)
mask[np.triu_indices_from(mask)] = True


with sns.axes_style("white"):
    sns.heatmap(corr1, mask = mask, square = True, annot = True, vmax = 1, linewidths = .5)

plt.title('Correlation Between Rainfall Statistics and Traffic Accidents by Month');

# %% [markdown]
# The correlation data between the various rainfall and sunshine data vs the number of accidents recorded do not show a clear pattern. On hind sight, other information should have been taken into account like data from all the meteorological stations around Singapore. An observation could be made about the maximum rainfall in a day recorded and the mean number of hours of sunshine in a day for the month to be the most correlated with the number of accidents, which suggests that perhaps we need to be finding data on weather statistics that affect visibility and compare them to the number of accidents. There is also a slight negative correlation between sunshine hours and accidents suggesting that perhaps additional data from visibility factors might be relevant to this study.

# %%
# Use kde = true and test with different bin values to get the closest shape to the actual distribution
sns.displot(accident_rain2['total_rainfall'], bins = 15, kde = True)

plt.title('Distribution of Total Rainfall Monthly from 2008 to 2021');

# %%
round(np.mean(accident_rain2['total_rainfall']),4)
# Out:
# 168.6446

# %%
np.median(accident_rain2['total_rainfall'])
# Out:
# 158.45

# %%
sns.displot(accident_rain2['total_rainfall'], bins = 15, kde = False)
plt.vlines(x = np.mean(accident_rain2['total_rainfall']), ymin = 0, ymax = 35, color = 'orange')
plt.vlines(x = np.median(accident_rain2['total_rainfall']), ymin = 0, ymax = 35, color = 'green')

plt.title('Distribution of Total Rainfall Monthly from 2008 to 2021');

# %% [markdown]
# Historgram is skewed right because there might be some outliers. The median and the mean are relatively close to each other. When the outliers are not taken into consideration, the distribution looks relatively normal.

# %%
# Use kde = true and test with different bin values to get the closest shape to the actual distribution
sns.displot(accident_rain2['no_of_rainy_days'], bins = 7, kde = True)

plt.title('Distribution of Number of Rainy Days Monthly from 2008 to 2021');

# %%
round(np.mean(accident_rain2['no_of_rainy_days']),4)
# Out:
# 14.5179

# %%
np.median(accident_rain2['no_of_rainy_days'])
# Out:
# 15.0

# %%
sns.displot(accident_rain2['no_of_rainy_days'], bins = 7, color = 'grey', kde = False)
plt.vlines(x = np.mean(accident_rain2['no_of_rainy_days']), ymin = 0, ymax = 45, color = 'orange')
plt.vlines(x = np.median(accident_rain2['no_of_rainy_days']), ymin = 0, ymax = 45, color = 'green')

plt.title('Distribution of Number of Rainy Days Monthly from 2008 to 2021');

# %% [markdown]
# Distribution is normal and the median and the mean are also relatively close to each other.

# %%
# Use kde = true and test with different bin values to get the closest shape to the actual distribution
sns.displot(accident_rain2['maximum_rainfall_in_a_day'], bins = 8, kde = True)

plt.title('Distribution of Maximum Rainfall Recorded in a Day Monthly from 2008 to 2021');

# %%
round(np.mean(accident_rain2['maximum_rainfall_in_a_day']), 4)
# Out:
# 47.6804

# %%
np.median(accident_rain2['maximum_rainfall_in_a_day'])
# Out:
# 42.45

# %%
sns.displot(accident_rain2['maximum_rainfall_in_a_day'], bins = 8, color = 'teal', kde = False)
plt.vlines(x = np.mean(accident_rain2['maximum_rainfall_in_a_day']), ymin = 0, ymax = 90, color = 'orange')
plt.vlines(x = np.median(accident_rain2['maximum_rainfall_in_a_day']), ymin = 0, ymax = 90, color = 'green')

plt.title('Distribution of Maximum Rainfall Recorded in a Day Monthly from 2008 to 2021');

# %% [markdown]
# Historgram is skewed right because there might be some outliers. The median and the mean are relatively close to each other. When the outliers are not taken into consideration, the distribution looks relatively normal.

# %%
# Use kde = true and test with different bin values to get the closest shape to the actual distribution
sns.displot(accident_rain2['mean_sunshine_hrs'], bins = 10, kde = True)

plt.title('Distribution of Mean Sunshine Hours Monthly from 2008 to 2021');

# %%
round(np.mean(accident_rain2['mean_sunshine_hrs']), 4)
# Out:
# 5.85

# %%
np.median(accident_rain2['mean_sunshine_hrs'])
# Out:
# 5.9

# %%
sns.displot(accident_rain2['mean_sunshine_hrs'], bins = 10, color = 'brown', kde = False)
plt.vlines(x = np.mean(accident_rain2['mean_sunshine_hrs']), ymin = 0, ymax = 40, color = 'orange')
plt.vlines(x = np.median(accident_rain2['mean_sunshine_hrs']), ymin = 0, ymax = 40, color = 'green')

plt.title('Distribution of Mean Sunshine Hours Monthly from 2008 to 2021');

# %% [markdown]
# Distribution is normal and the median and the mean are also relatively close to each other.

# %%
# Use kde = true and test with different bin values to get the closest shape to the actual distribution
sns.displot(accident_rain2['num_of_accidents'], bins = 10, kde = True)

plt.title('Distribution of Number of Traffic Accidents Monthly from 2008 to 2021');

# %%
sns.displot(accident_rain2['num_of_accidents'], bins = 10, color = 'pink', kde = False)
plt.vlines(x = np.mean(accident_rain2['num_of_accidents']), ymin = 0, ymax = 65, color = 'orange')
plt.vlines(x = np.median(accident_rain2['num_of_accidents']), ymin = 0, ymax = 65, color = 'green')

plt.title('Distribution of Number of Traffic Accidents Monthly from 2008 to 2021');

# %% [markdown]
# Distribution is skewed left, but could be more pronounced due to outliers. (Noted that 2020 and 2021 covid lockdown could have affected the numbers). Mean and median are relatively close to each other.

# %%
sns.boxplot(data = accident_rain2.total_rainfall, orient = 'h')
plt.title('Total Rainfall Monthly 2008-2021')
plt.xlabel("Rainfall in millimeters", fontsize = 10);

# %% [markdown]
# Total Rainfall Monthly: 75% of the months between the years of 2008 and 2021 had less than 250ml of total rainfall. 25% of the months actually widely spread values for the total rainfall recorded, with 2 very clear outlier months that recorded unsually high amounts of total rainfall. It might be worth noting the years and months that these results were recorded in to check if there were any influencing factors or phenomenon that caused this. 25% of the data collected reflects months with less than 100 mm of rainfall. The median value recorded was 158.45mm of rainfall. It could also be worth noting if the months that record these numbers are similar year on year to see obvious dry and wet seasons.

# %%
sns.boxplot(data = accident_rain2.no_of_rainy_days, orient = 'h', color = 'grey')
plt.title('Number of Rainy Days Monthly 2008-2021')
plt.xlabel("Days", fontsize = 10);

# %% [markdown]
# Number of Rainy Days Monthly: 50% of the data collected reflects between 11 to 19 rainy days. 25% of the months recorded between 11 and 1 rainy day in the month. 25% of the data recorded between 19 and 27 rainy days in a month. The median value is 15 days. There aren't any clear outliers in this boxplot which could mainly be because there are only a maximum of between 28 to 31 days in a month.

# %%
sns.boxplot(data = accident_rain2.maximum_rainfall_in_a_day, orient = 'h', color = 'teal')
plt.title('Maximum Rainfall in a Day Monthly 2008-2021')
plt.xlabel("Rainfall in millimeters", fontsize = 10);

# %% [markdown]
# Maximum Rainfall in a Day Monthly: Almost all of the data reflects a maximum rainfall collected in one day to be under 100 mm. There are several outliers that recorded values that range between 100mm and 150mm, and 2 extreme cases that reorded values of above 200mm. The rest of the data collected is relatively normally distributed around the median which is 42.45mm.

# %%
sns.boxplot(data = accident_rain2.num_of_accidents, orient = 'h', color = 'pink')
plt.title('Number of Traffic Accidents Monthly 2008-2021')
plt.xlabel("Number of accidents", fontsize = 10);

# %% [markdown]
# Number of Traffic Accidents Monthly: There are a number of outliers with unusually low numbers of accidents below 550. 25% of the data collected has values between 510 to 620 accidents. The middle 50% of the data collected ranges between 620 to 710 accidents, and the remaining 25% of the months have recorded values between 710 to 810 accidents in a month. It might be worth noting that between 2020 and 2021, covid lockdown was in place and that road usage was extremely low. Outside of these values, perhaps it would also be worth noting that road usage during months with school holidays are also lower than normal months.

# %%
accident_rain2.head()
# Out:
#     mth_year  mth  year  total_rainfall  maximum_rainfall_in_a_day  \
# 0 2008-01-01    1  2008           262.6                      123.1
# 1 2008-02-01    2  2008           129.2                       48.5
# 2 2008-03-01    3  2008           294.1                       48.1
# 3 2008-04-01    4  2008            87.2                       34.2
# 4 2008-05-01    5  2008           124.9                       42.3
#
#    no_of_rainy_days  mean_sunshine_hrs  num_of_accidents
# 0                19                6.1               750
# 1                 8                5.5               606
# 2                16                4.3               713
# 3                13                6.0               718
# 4                11                6.6               706

# %%
# Establish the size of the figure.
plt.figure(figsize = (14, 7))

# Create scatterplot of Number of Accidents versus Total Rainfall Monthly.
plt.scatter(accident_rain2['num_of_accidents'], #x-axis
            accident_rain2['total_rainfall']); #y-axis

plt.title("Number of Accidents Versus Total Rainfall Monthly", fontsize = 18)
plt.xlabel("Number of Accidents Monthly", fontsize = 16)
plt.ylabel("Total Rainfall Monthly (mm)", fontsize = 16);

# %%
# Establish the size of the figure.
plt.figure(figsize = (14, 7))

# Create scatterplot of Number of Accidents versus Number of Rainy Days.
plt.scatter(accident_rain2['num_of_accidents'], #x-axis
            accident_rain2['no_of_rainy_days'], #y-axis
           color = 'grey'); 

plt.title("Number of Accidents Versus Number of Rainy Days", fontsize = 18)
plt.xlabel("Number of Accidents Monthly", fontsize = 16)
plt.ylabel("Number of Rainy Days Monthly", fontsize = 16);

# %%
# Establish the size of the figure.
plt.figure(figsize = (14, 7))

# Create scatterplot of Number of Accidents versus Maximum Rainfall in a Day.
plt.scatter(accident_rain2['num_of_accidents'], #x-axis
            accident_rain2['maximum_rainfall_in_a_day'], #y-axis
           color = 'teal'); 

plt.title("Number of Accidents Versus Maximum Rainfall in a Day per Month", fontsize = 18)
plt.xlabel("Number of Accidents Monthly", fontsize = 16)
plt.ylabel("Number of Maximum Rainfall in a Day Monthly (mm)", fontsize = 16);

# %%
# Establish the size of the figure.
plt.figure(figsize = (14, 7))

# Create scatterplot of Number of Accidents versus Mean Hours of Sunshine Monthly.
plt.scatter(accident_rain2['num_of_accidents'], #x-axis
            accident_rain2['mean_sunshine_hrs'], #y-axis
           color = 'brown'); 

plt.title("Number of Accidents Versus Total Rainfall Monthly", fontsize = 18)
plt.xlabel("Number of Accidents Monthly", fontsize = 16)
plt.ylabel("Mean Hours of Sunshine per Day Monthly", fontsize = 16);

# %% [markdown]
# After plotting the scatter plots of all the different weather variables versus the number of accidents recorded, no clear trends stand out. This could be an indicator that on it's own, weather does not significantly affect the number of traffic accidents and it is worth further refining the different subsets of weather data, combined with other pertinent data that affects road conditions that we should be using to properly allocate Traffic Police and Civil Defence resources.

# %%
# Plot line graphs to try and determine if there are any over lapping trends between weather data and traffic accidents.

plt.plot(accident_rain2['mth_year'], accident_rain2['num_of_accidents'],
                  label = 'Accidents', color = 'red');

plt.title('Number of Accidents Monthly over Time')
plt.ylabel('Number of accidents')
plt.xlabel('Year')
plt.legend(loc = 'upper right', fontsize = 10);

# %%
plt.plot(accident_rain2['mth_year'], accident_rain2['total_rainfall'],
                  label = 'Monthly Total Rainfall');

plt.title('Total Rainfall Monthly over Time')
plt.ylabel('Total Rainfall (mm)')
plt.xlabel('Year')
plt.legend(loc = 'upper left', fontsize = 10);

# %%
plt.plot(accident_rain2['mth_year'], accident_rain2['no_of_rainy_days'],
                  label = 'Number of rainy days', color = 'grey');

plt.title('Number of Rainy Days Monthly over Time')
plt.ylabel('Days')
plt.xlabel('Year')
plt.legend(loc = 'upper left', fontsize = 10);

# %%
plt.plot(accident_rain2['mth_year'], accident_rain2['maximum_rainfall_in_a_day'],
                  label = 'Max rainfall in a day per month', color = 'teal');

plt.title('Maximum Rainfall in a Day per Month over Time')
plt.ylabel('Rainfall (mm)')
plt.xlabel('Year')
plt.legend(loc = 'upper center', fontsize = 10);

# %%
plt.plot(accident_rain2['mth_year'], accident_rain2['mean_sunshine_hrs'],
                  label = 'Mean sunshine hrs per day', color = 'brown');

plt.title('Mean Hours of Sunshine in a Day per Month over Time')
plt.ylabel('Hours')
plt.xlabel('Year')
plt.legend(loc = 'upper left', fontsize = 10);

# %% [markdown]
# The line graphs seem to reaffirm what we concluded above in the scatter plots. That the weather data as it is, does not show any meaningful correlation or trends when compared with accident statistics.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Conclusion: Given the lack of a correlation or clear pattern when comparing weather statistics against traffic accident data, we can conclude that weather on its own is not a significant reason for traffic accidents in Singapore.
#
# Recommendations: For now, I would recommend maintaining the status quo in terms of resource allocation during months with high rainfall numbers. I would also recommend that we explore using the following data, together with weather data when determining how to properly allocate manpower and resources.
#
# 1. Obtain weather data from other parts of Singapore and compare them to the corresponding accident statistics in that area.
# 2. Due to the drastic fall in accidents in 2020 and 2021, I would suggest looking at the correlation between road usage and traffic accidents.
# 3. A quick Google search online will yield many articles suggesting that visibility is a factor in the number of accidents. I would suggest obtaining weather data specifically looking at months with stormy weather and intense rainfall against traffic accident statistics.
#
# Based on the outliers found in traffic accident data distribution due to the inclusion of 2020 and 2021 statistics, I would recommend that instead of allocating additional resources to Traffic Police and Civil Defence during the rainy season, resources should be directed to reducing road usage in general in order to bring down the number traffic accidents.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
